# %% [markdown]
# <a href="https://colab.research.google.com/github/MariaPazGallitrico/TelecomX--Challenge2/blob/main/TelecomX-Challenge2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_json('/datos_hosting.json')
